# %% [markdown]
# <a href="https://colab.research.google.com/github/kollurusuresh-max/Test01/blob/main/SumOfMultiples.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
total_sum = 0
for i in range(1, 100):
    if i % 3 == 0 or i % 5 == 0:
        total_sum += i
print(total_sum)
# Out:
# 2318
